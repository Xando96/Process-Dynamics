# %% [markdown]
# # Process Dynamics (CPN321)
#
# ### 0. Getting started
#
# * [Cheatsheet](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/0_Getting_Started/Cheatsheet.ipynb)
# * [Extra Python](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/0_Getting_Started/Extra_Python.ipynb)
# * [Notebook introduction](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/0_Getting_Started/Notebook_introduction.ipynb)
#
# ### 1. Modelling
#
# * [Modelling basics](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/1_Modelling/1_Modelling_basics.ipynb)
# * [Modelling equations and introduction to simulation](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/1_Modelling/2_Modelling_equations.ipynb)
# * [Modelling partial differential equations](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/1_Modelling/3_Modelling_PDE.ipynb)
# * [Control system instrumentation](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/1_Modelling/4_Control_system_instrumentation.ipynb)
#
# ### 2. Time domain simulation
#
# * [Equation solving tools](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/2_Time_domain_simulation/Equation_solving_tools.ipynb)
# * [Draining cup](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/2_Time_domain_simulation/Draining_cup.ipynb)
# * [Numeric representation](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/2_Time_domain_simulation/Numeric_representation.ipynb)
# * [Mixing system](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/2_Time_domain_simulation/Mixing_system.ipynb)
#
# ### 3. Linear systems
#
# * [Linearisation](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/3_Linear_systems/Linearisation.ipynb)
# * [Laplace transforms](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/3_Linear_systems/Laplace_transforms.ipynb)
# * [Convolution](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/3_Linear_systems/Convolution.ipynb)
#
# ### 4. First and second order system dynamics
#
# * [Standard process inputs](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/4_First_and_second_order_system_dynamics/Standard_process_inputs.ipynb)
# * [First order systems](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/4_First_and_second_order_system_dynamics/First_order_systems.ipynb)
# * [Second order systems](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/4_First_and_second_order_system_dynamics/Second_order_systems.ipynb)
# * [Sinusoidal response](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/4_First_and_second_order_system_dynamics/Sinusoidal_response.ipynb)
#
# ### 5. Complex system dynamics
#
# * [Block diagram simplification](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/5_Complex_system_dynamics/Block_diagram_simplification.ipynb)
# * [Random response generator](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/5_Complex_system_dynamics/Random_response_generator.ipynb)
# * [Approximation](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/5_Complex_system_dynamics/Approximation.ipynb)
# * [Simulation of arbitrary transfer functions](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/5_Complex_system_dynamics/Simulation_of_arbitrary_transfer_functions.ipynb)
#
# ### 6. Multivariable system representations
#
# * [State space](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/6_Multivariable_system_representation/State_space.ipynb)
# * [Justifying vectors and matrices](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/6_Multivariable_system_representation/Justify.ipynb)
# * [Transfer function matrices](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/6_Multivariable_system_representation/Transfer_function_matrices.ipynb)
#
# ### 7. System Identification
#
# * [Regression](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/7_System_identification/Regression.ipynb)
# * [Dynamic model parameter estimation](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/7_System_identification/Dynamic_model_parameter_estimation.ipynb)
# * [Identifying discrete-time models](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/7_System_identification/Identifying_discrete-time_models.ipynb)
# * [Neural networks](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/7_System_identification/Neural_networks.ipynb)
#
# ### 8. Frequency domain
#
# * [Fourier series](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/8_Frequency_domain/Fourier_series.ipynb)
# * [Frequency response plots](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/8_Frequency_domain/Frequency_response_plots.ipynb)
# * [Asymptotic Bode diagrams](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/8_Frequency_domain/Asymptotic_Bode_diagrams.ipynb)
#
# ### 9. Sampled systems
#
# * [Aliasing](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/9_Sampled_systems/Aliasing.ipynb)
# * [Filtering](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/9_Sampled_systems/Filtering.ipynb)
# * [The z-transform](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/9_Sampled_systems/The_z-transform.ipynb)
# * [The z-domain and continuous systems](https://nbviewer.jupyter.org/github/reubens9/Process-Dynamics/tree/master/9_Sampled_systems/The_z-domain_and_continuous_systems.ipynb)
